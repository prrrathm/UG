# %% [markdown]
# # Reading files as data frame with following capabilities:
#
#
# 1.   Indexing: Reading multiple columns alongwith colulmn header (optional)
# 2.   Type inference and data conversion
#
# 1.   DataTime parsing: combining multiple columns from the file and use as a single column in DF
# 2.   Iterating: reading files in chunks, useful in case file is large
#
# 1.  Unclean data issues: Skipping rows/headers etc.

# %% [markdown]
# ## pandas features a number of functions for reading tabular data as a DataFrame
# object. using read_csv() and read_table()

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %% [markdown]
# ## in google colab do the following
# from google.colab import files
# uploaded = files.upload()
# uploaded
# tipsdata = pd.read_csv("/content/fname.csv")

# %% [markdown]
# use of cat command to show csv file content, where file has column names

# %%
## colab code
# !cat /content/weather.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
print(os. getcwd() )
# Out:
# d:\cs(h)Vsem Data analysis and visulaization 2021\programs\pandas

# %% [markdown]
# ## Two ways to read csv file either as table or dataframe
# ### By default first row is used as coulmn labels(Header)

# %%
pd.read_csv('weather.csv')
# Out:
#     Season   Weather  Tourist Labels
# 0   Summer  Pleasant     like    Yes
# 1   Summer       Hot  dislike    Yes
# 2   Summer  Pleasant     like    Yes
# 3   winter     Harsh     like    Yes
# ..     ...       ...      ...    ...
# 5   autumn       Dry  dislike    Yes
# 6   autumn  Pleasant  dislike    Yes
# 7   autumn     Harsh      NaN     No
# 8   Spring  Pleasant     like    NaN
#
# [9 rows x 4 columns]

# %% [markdown]
# ## in case no header, then mention header=None

# %%
pd.read_csv('weather.csv', header=None)
# Out:
#          0         1        2       3
# 0   Season   Weather  Tourist  Labels
# 1   Summer  Pleasant     like     Yes
# 2   Summer       Hot  dislike     Yes
# 3   Summer  Pleasant     like     Yes
# ..     ...       ...      ...     ...
# 6   autumn       Dry  dislike     Yes
# 7   autumn  Pleasant  dislike     Yes
# 8   autumn     Harsh      NaN      No
# 9   Spring  Pleasant     like     NaN
#
# [10 rows x 4 columns]

# %% [markdown]
# ## setting header=0 takes first row in file as colunnames

# %%
data_weather_tab = pd.read_csv("weather.csv",header=0,sep="\t") 
print(data_weather_tab.columns)  
print(data_weather_tab)
# Out:
# Index(['Season,Weather,Tourist,Labels'], dtype='object')
#    Season,Weather,Tourist,Labels
# 0       Summer,Pleasant,like,Yes
# 1         Summer,Hot,dislike,Yes
# 2       Summer,Pleasant,like,Yes
# 3          winter,Harsh,like,Yes
# ..                           ...
# 5         autumn,Dry,dislike,Yes
# 6    autumn,Pleasant,dislike,Yes
# 7           autumn,Harsh,NULL,No
# 8      Spring,Pleasant,like,NULL
#
# [9 rows x 1 columns]

# %%
data_weather = pd.read_csv("weather.csv",header=0,sep=",") 
print(data_weather.columns)  
print(data_weather)
# Out:
# Index(['Season', 'Weather', 'Tourist', 'Labels'], dtype='object')
#     Season   Weather  Tourist Labels
# 0   Summer  Pleasant     like    Yes
# 1   Summer       Hot  dislike    Yes
# 2   Summer  Pleasant     like    Yes
# 3   winter     Harsh     like    Yes
# ..     ...       ...      ...    ...
# 5   autumn       Dry  dislike    Yes
# 6   autumn  Pleasant  dislike    Yes
# 7   autumn     Harsh      NaN     No
# 8   Spring  Pleasant     like    NaN
#
# [9 rows x 4 columns]

# %% [markdown]
# ## setting header to None takes first row of column names as the record of file. Use appropriate seperator for field

# %%
pd.read_csv('weather.csv', header=None,sep=',')
# Out:
#         0         1        2       3
# 0  Season   Weather  Tourist  Labels
# 1  Summer  Pleasant     like     Yes
# 2  Summer       Hot  dislike     Yes
# 3  Summer  Pleasant     like     Yes
# 4  winter     Harsh     like     Yes
# 5  winter  Pleasant     like      No
# 6  autumn       Dry  dislike     Yes
# 7  autumn  Pleasant  dislike     Yes
# 8  autumn     Harsh      NaN      No
# 9  Spring  Pleasant     like     NaN

# %% [markdown]
# ## reading file with no header and field seperator " " (space)

# %%
data = pd.read_csv("marks-noheader.csv",header=None,sep=" ")
print(data.columns)  
print(data)
# Out:
# Int64Index([0, 1, 2], dtype='int64')
#     0   1  2
# 0  34  56  A
# 1  45  56  B
# 2  56  67  C
# 3  67  67  D
# 4  67  78  E

# %% [markdown]
# ## While reading set column names (sub1, subj2, name)

# %%
data = pd.read_csv("marks-noheader.csv",sep=" ",names=['sub1','sub2','name'])
print(data.columns)  
print(data)
# Out:
# Index(['sub1', 'sub2', 'name'], dtype='object')
#    sub1  sub2 name
# 0    34    56    A
# 1    45    56    B
# 2    56    67    C
# 3    67    67    D
# 4    67    78    E

# %% [markdown]
# ## By default row index are 0 to n-1. a coulmn data can be set as row indexes

# %%
data = pd.read_csv("marks-noheader.csv",sep=" ",names=['sub1','sub2','name'],index_col='name')
print(data.columns)  
print(data)
# Out:
# Index(['sub1', 'sub2'], dtype='object')
#       sub1  sub2
# name
# A       34    56
# B       45    56
# C       56    67
# D       67    67
# E       67    78

# %% [markdown]
# ## read_table() : Load delimited data from a file, URL, or file-like object; use tab ('\t') as default delimite. pandas read_table() does type inference as done in read_csv(). Used for text files with delimiter tab

# %%
pd.read_table('weather.csv', sep=',')
# Out:
#    Season   Weather  Tourist Labels
# 0  Summer  Pleasant     like    Yes
# 1  Summer       Hot  dislike    Yes
# 2  Summer  Pleasant     like    Yes
# 3  winter     Harsh     like    Yes
# 4  winter  Pleasant     like     No
# 5  autumn       Dry  dislike    Yes
# 6  autumn  Pleasant  dislike    Yes
# 7  autumn     Harsh      NaN     No
# 8  Spring  Pleasant     like    NaN

# %% [markdown]
# ## in case there are different spaces within columns of a record

# %%
df=pd.read_csv('ex3.txt', sep='\s+',engine='python')

# %%
print(len(df.columns))
display(df)
# Out:
# 3
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %% [markdown]
# ## operations on the data read:
# ## number of rows and number of columns in data

# %%
print(len(data.columns))
print(len(data))
# Out:
# 2
# 5

# %% [markdown]
# ## number of valid values in each column/rows

# %%
data.count(axis='columns')
# Out:
# name
# A    2
# B    2
# C    2
# D    2
# E    2
# dtype: int64

# %%
data_weather
# Out:
#    Season   Weather  Tourist Labels
# 0  Summer  Pleasant     like    Yes
# 1  Summer       Hot  dislike    Yes
# 2  Summer  Pleasant     like    Yes
# 3  winter     Harsh     like    Yes
# 4  winter  Pleasant     like     No
# 5  autumn       Dry  dislike    Yes
# 6  autumn  Pleasant  dislike    Yes
# 7  autumn     Harsh      NaN     No
# 8  Spring  Pleasant     like    NaN

# %%
data_weather.count(axis='rows')
# Out:
# Season     9
# Weather    9
# Tourist    8
# Labels     8
# dtype: int64

# %%
data_weather.count(axis='columns')

# %% [markdown]
# # Use of hierrachical index (multiple groups)

# %%
hierrachydata=pd.read_csv("course-marks.csv",sep=",",header=0,index_col=['Course','Rollno'])
print(hierrachydata)
# Out:
#                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1       67.0    56.0      89
#        Z-2       67.0    45.0      76
#        Z-3       78.0    56.0      56
#        Z-4       76.0    67.0      45
#        Z-5       68.0    57.0      90
#        Z-6       68.0    46.0      77
#        Z-7       79.0    57.0      57
# PS     Z-1       77.0    68.0      46
#        Z-2       69.0    58.0      91
#        Z-3       69.0    47.0      78
#        Z-4       80.0    58.0      58
#        Z-5       78.0    69.0      47
#        Z-6       70.0    59.0      92
#        Z-7       70.0    48.0      79
#        Z-8       60.0    80.0      80
#        Z-         0.0   -20.0      -2
#        Z-0        NaN     NaN       2

# %%
hierrachydata.index
# Out:
# MultiIndex([('PMCS', 'Z-1'),
#             ('PMCS', 'Z-2'),
#             ('PMCS', 'Z-3'),
#             ('PMCS', 'Z-4'),
#             ('PMCS', 'Z-5'),
#             ('PMCS', 'Z-6'),
#             ('PMCS', 'Z-7'),
#             (  'PS', 'Z-1'),
#             (  'PS', 'Z-2'),
#             (  'PS', 'Z-3'),
#             (  'PS', 'Z-4'),
#             (  'PS', 'Z-5'),
#             (  'PS', 'Z-6'),
#             (  'PS', 'Z-7'),
#             (  'PS', 'Z-8'),
#             (  'PS',  'Z-'),
#             (  'PS', 'Z-0')],
#            names=['Course', 'Rollno'])

# %%
pd.isnull(hierrachydata)
# Out:
#                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1      False   False   False
#        Z-2      False   False   False
#        Z-3      False   False   False
#        Z-4      False   False   False
#        Z-5      False   False   False
#        Z-6      False   False   False
#        Z-7      False   False   False
# PS     Z-1      False   False   False
#        Z-2      False   False   False
#        Z-3      False   False   False
#        Z-4      False   False   False
#        Z-5      False   False   False
#        Z-6      False   False   False
#        Z-7      False   False   False
#        Z-8      False   False   False
#        Z-       False   False   False
#        Z-0       True    True   False

# %% [markdown]
# ## Expilicitly mentioning the list of values to be considered as NA

# %%
hierrachydata=pd.read_csv("course-marks.csv",sep=",",header=0,index_col=['Course','Rollno'],na_values=['NULL','NA','0'])
print(hierrachydata)
print(len(hierrachydata))
# Out:
#                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1       67.0    56.0      89
#        Z-2       67.0    45.0      76
#        Z-3       78.0    56.0      56
#        Z-4       76.0    67.0      45
#        Z-5       68.0    57.0      90
#        Z-6       68.0    46.0      77
#        Z-7       79.0    57.0      57
# PS     Z-1       77.0    68.0      46
#        Z-2       69.0    58.0      91
#        Z-3       69.0    47.0      78
#        Z-4       80.0    58.0      58
#        Z-5       78.0    69.0      47
#        Z-6       70.0    59.0      92
#        Z-7       70.0    48.0      79
#        Z-8       60.0    80.0      80
#        Z-         NaN   -20.0      -2
#        Z-0        NaN     NaN       2
# 17
# <bound method DataFrame.info of                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1       67.0    56.0      89
#        Z-2       67.0    45.0      76
#        Z-3       78.0    56.0      56
#        Z-4       76.0    67.0      45
# ...

# %%
print(hierrachydata.info)
# Out:
# <bound method DataFrame.info of                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1       67.0    56.0      89
#        Z-2       67.0    45.0      76
#        Z-3       78.0    56.0      56
#        Z-4       76.0    67.0      45
#        Z-5       68.0    57.0      90
#        Z-6       68.0    46.0      77
#        Z-7       79.0    57.0      57
# PS     Z-1       77.0    68.0      46
#        Z-2       69.0    58.0      91
#        Z-3       69.0    47.0      78
#        Z-4       80.0    58.0      58
#        Z-5       78.0    69.0      47
#        Z-6       70.0    59.0      92
#        Z-7       70.0    48.0      79
#        Z-8       60.0    80.0      80
#        Z-         NaN   -20.0      -2
#        Z-0        NaN     NaN       2>

# %% [markdown]
# ## Explicitly skipping some rows

# %% [markdown]
# Adding a row with NA values and mentioning Different NA sentinels for each column in a dict

# %%
hierrachydata=pd.read_csv("course-marks.csv",sep=",",header=0,index_col=['Course'])
print(hierrachydata)
print("length of DF=",len(hierrachydata))
# Out:
#        Rollno  Marks1  Marks2  Marks3
# Course
# PMCS      Z-1    67.0    56.0      89
# PMCS      Z-2    67.0    45.0      76
# PMCS      Z-3    78.0    56.0      56
# PMCS      Z-4    76.0    67.0      45
# PMCS      Z-5    68.0    57.0      90
# PMCS      Z-6    68.0    46.0      77
# PMCS      Z-7    79.0    57.0      57
# PS        Z-1    77.0    68.0      46
# PS        Z-2    69.0    58.0      91
# PS        Z-3    69.0    47.0      78
# PS        Z-4    80.0    58.0      58
# PS        Z-5    78.0    69.0      47
# PS        Z-6    70.0    59.0      92
# PS        Z-7    70.0    48.0      79
# PS        Z-8    60.0    80.0      80
# PS         Z-     0.0   -20.0      -2
# PS        Z-0     NaN     NaN       2
# length of DF= 17

# %%
hierrachydata.index
# Out:
# Index(['PMCS', 'PMCS', 'PMCS', 'PMCS', 'PMCS', 'PMCS', 'PMCS', 'PS', 'PS',
#        'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS'],
#       dtype='object', name='Course')

# %%
dict1={'Rollno':'Z-20','Marks1':-2,'Marks2':-3,'Marks3':78}
s1=pd.Series(dict1,name='PMCS')
hierrachydata=hierrachydata.append(s1)
print(len(hierrachydata))
print(hierrachydata)
#print(hierrachydata.info)
# Out:
# 18
#        Rollno  Marks1  Marks2  Marks3
# Course
# PMCS      Z-1    67.0    56.0      89
# PMCS      Z-2    67.0    45.0      76
# PMCS      Z-3    78.0    56.0      56
# PMCS      Z-4    76.0    67.0      45
# PMCS      Z-5    68.0    57.0      90
# PMCS      Z-6    68.0    46.0      77
# PMCS      Z-7    79.0    57.0      57
# PS        Z-1    77.0    68.0      46
# PS        Z-2    69.0    58.0      91
# PS        Z-3    69.0    47.0      78
# PS        Z-4    80.0    58.0      58
# PS        Z-5    78.0    69.0      47
# PS        Z-6    70.0    59.0      92
# PS        Z-7    70.0    48.0      79
# PS        Z-8    60.0    80.0      80
# PS         Z-     0.0   -20.0      -2
# PS        Z-0     NaN     NaN       2
# PMCS     Z-20    -2.0    -3.0      78

# %% [markdown]
# ## use dictionary for mentioning different nullvalues for different columns

# %%
#!cat /content/course-marks-NA.csv
missing={'Rollno':['Z-'],'Marks1':['NA',0],'Marks2':['NaN',-20],'Marks3':['NA',0,-2]}

# %%
hierrachydata=pd.read_csv("course-marks-NA.csv",sep=",",header=0,index_col=['Course'],na_values=missing)
print(hierrachydata)
# Out:
#        Rollno  Marks1  Marks2  Marks3
# Course
# PMCS      Z-1    67.0    56.0    89.0
# PMCS      Z-2    67.0    45.0    76.0
# PMCS      Z-3    78.0    56.0    56.0
# PMCS      Z-4    76.0    67.0    45.0
# PMCS      Z-5    68.0    57.0    90.0
# PMCS      Z-6    68.0    46.0    77.0
# PMCS      Z-7    79.0    57.0    57.0
# PS        Z-1    77.0    68.0    46.0
# PS        Z-2    69.0    58.0    91.0
# PS        Z-3    69.0    47.0    78.0
# PS        Z-4    80.0    58.0    58.0
# PS        Z-5    78.0    69.0    47.0
# PS        Z-6    70.0    59.0    92.0
# PS        Z-7    70.0    48.0    79.0
# PS        Z-8    60.0    80.0    80.0
# PS        NaN     NaN     NaN     NaN
# PS        Z-0     NaN     NaN     2.0

# %% [markdown]
# ##  droprows with any NA

# %%
df1 = hierrachydata.dropna()
print(df1)
# Out:
#        Rollno  Marks1  Marks2  Marks3
# Course
# PMCS      Z-1    67.0    56.0    89.0
# PMCS      Z-2    67.0    45.0    76.0
# PMCS      Z-3    78.0    56.0    56.0
# PMCS      Z-4    76.0    67.0    45.0
# PMCS      Z-5    68.0    57.0    90.0
# PMCS      Z-6    68.0    46.0    77.0
# PMCS      Z-7    79.0    57.0    57.0
# PS        Z-1    77.0    68.0    46.0
# PS        Z-2    69.0    58.0    91.0
# PS        Z-3    69.0    47.0    78.0
# PS        Z-4    80.0    58.0    58.0
# PS        Z-5    78.0    69.0    47.0
# PS        Z-6    70.0    59.0    92.0
# PS        Z-7    70.0    48.0    79.0
# PS        Z-8    60.0    80.0    80.0

# %% [markdown]
# ## skip explicitly few rows and get only specified number of rows

# %%
hierrachydata=pd.read_csv("course-marks.csv",header=0,index_col=['Course','Rollno'],skiprows=[2,8],nrows=10)
print(hierrachydata)
print("rows= ",len(hierrachydata))
# Out:
#                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1         67      56      89
#        Z-3         78      56      56
#        Z-4         76      67      45
#        Z-5         68      57      90
#        Z-6         68      46      77
#        Z-7         79      57      57
# PS     Z-2         69      58      91
#        Z-3         69      47      78
#        Z-4         80      58      58
#        Z-5         78      69      47
# rows=  10

# %% [markdown]
# ## setting pandas option to display only n rows at a time

# %%
pd.options.display.max_rows = 8
print(hierrachydata)
# Out:
#                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1         67      56      89
#        Z-3         78      56      56
#        Z-4         76      67      45
#        Z-5         68      57      90
# ...               ...     ...     ...
# PS     Z-2         69      58      91
#        Z-3         69      47      78
#        Z-4         80      58      58
#        Z-5         78      69      47
#
# [10 rows x 3 columns]

# %% [markdown]
# # reading big files from dataset bundled in sklearn library

# %%
from sklearn.datasets import load_iris
irisdata = load_iris()
type(irisdata)
# Out:
# sklearn.utils.Bunch

# %%
irisdata.data[:40]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
irisDF = pd.DataFrame(irisdata.data, columns=irisdata.feature_names)
irisDF.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
irisDF.iloc[[10, 25, 30]]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 10                5.4               3.7                1.5               0.2
# 25                5.0               3.0                1.6               0.2
# 30                4.8               3.1                1.6               0.2

# %% [markdown]
# ## loading few rows in DF

# %%
irisDF = pd.DataFrame(irisdata.data[:40], columns=irisdata.feature_names)
irisDF.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ## use the chunksize argument to pandas.read_csv gives  an iterator over DataFrames, rather than one single DataFrame. Each DataFrame is the next chunksize lines of the CSV:

# %%
irischunk=pd.read_csv('Iris.csv',header=0,chunksize=5)
print(irischunk)

# %%
for piece in irischunk:
  print(piece)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa
# ...

# %% [markdown]
# ## processing each chunk and writing to CSV

# %%
irischunk=pd.read_csv('Iris.csv',header=0,chunksize=10)
tot = pd.Series([]); count=0
for piece in irischunk:
  #print(piece)
  tot = tot.add(piece['Species'].value_counts(), fill_value=0)
  if count==16:
    break
  count+=1
tot = tot.sort_values(ascending=False)
print(tot)
# Out:
# Iris-setosa        50.0
# Iris-versicolor    50.0
# Iris-virginica     50.0
# dtype: float64
# C:\Users\SHARAN~1\AppData\Local\Temp/ipykernel_22932/1302632682.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   tot = pd.Series([]); count=0

# %%
tot
# Out:
# Iris-setosa        50.0
# Iris-versicolor    50.0
# Iris-virginica     50.0
# dtype: float64

# %%
tot.sort_index(ascending=False)
# Out:
# Iris-virginica     50.0
# Iris-versicolor    50.0
# Iris-setosa        50.0
# dtype: float64

# %%
tot.to_csv('totalIris.csv')  #writig series/dataframe to the file

# %%
pd.read_csv('totalIris.csv')
# Out:
#         Unnamed: 0     0
# 0      Iris-setosa  50.0
# 1  Iris-versicolor  50.0
# 2   Iris-virginica  50.0

# %%
DF_new=pd.read_table('weather-1.txt', header=None)

# %%
DF_new[:10]
# Out:
#         0         1        2       3
# 0  Season   Weather  Tourist  Labels
# 1  Summer  Pleasant     like     Yes
# 2  Summer       Hot  dislike     Yes
# 3  Summer  Pleasant     like     Yes
# 4  winter     Harsh     like     Yes
# 5  winter  Pleasant     like      No
# 6  autumn       Dry  dislike     Yes
# 7  autumn  Pleasant  dislike     Yes
# 8  autumn     Harsh      NaN      No
# 9  Spring  Pleasant     like     NaN

# %% [markdown]
# # writing to a csv file with user specified field seperator

# %%
hierrachydata
# Out:
#                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1         67      56      89
#        Z-3         78      56      56
#        Z-4         76      67      45
#        Z-5         68      57      90
#        Z-6         68      46      77
#        Z-7         79      57      57
# PS     Z-2         69      58      91
#        Z-3         69      47      78
#        Z-4         80      58      58
#        Z-5         78      69      47

# %%
import sys
print(hierrachydata)
hierrachydata.to_csv('newfile.txt', sep='|',na_rep=[0])  #null values by 0
hierrachydata.to_csv(sys.stdout, sep='|',header=False) # no frame header in the file
# Out:
#                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1         67      56      89
#        Z-3         78      56      56
#        Z-4         76      67      45
#        Z-5         68      57      90
#        Z-6         68      46      77
#        Z-7         79      57      57
# PS     Z-2         69      58      91
#        Z-3         69      47      78
#        Z-4         80      58      58
#        Z-5         78      69      47
# PMCS|Z-1|67|56|89
# PMCS|Z-3|78|56|56
# PMCS|Z-4|76|67|45
# PMCS|Z-5|68|57|90
# PMCS|Z-6|68|46|77
# PMCS|Z-7|79|57|57
# PS|Z-2|69|58|91
# PS|Z-3|69|47|78
# PS|Z-4|80|58|58
# PS|Z-5|78|69|47

# %%
dates = pd.date_range('1/1/2000', periods=10)  #fn to generated dates
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.arange(10), index=dates)
ts.name="dates"
ts.to_csv(sys.stdout,header=True,sep=' ')
# Out:
#  dates
# 2000-01-01 0
# 2000-01-02 1
# 2000-01-03 2
# 2000-01-04 3
# 2000-01-05 4
# 2000-01-06 5
# 2000-01-07 6
# 2000-01-08 7
# 2000-01-09 8
# 2000-01-10 9

# %% [markdown]
# # Excel files

# %% [markdown]
# ## reading a excel file

# %%
xlsx = pd.ExcelFile('mixed-data-sec-choices.xlsx')

# %%
xlsx.sheet_names
# Out:
# ['mixed-data-updated-choices', 'courses', 'Sheet1']

# %%
pd.read_excel(xlsx, xlsx.sheet_names[0])
# Out:
#     S.No Name  Roll No                                         Course  Sem  \
# 0      1   AA   XC-913       B.SC. PHYSICAL SCIENCES WITH ELECTRONICS    3
# 1      2   AB   XC-748  B.SC. PHYSICAL SCIENCES WITH COMPUTER SCIENCE    3
# 2      3   AC   XC-713  B.SC. PHYSICAL SCIENCES WITH COMPUTER SCIENCE    3
# 3      4   AA   XC-907       B.SC. PHYSICAL SCIENCES WITH ELECTRONICS    3
# 4      5   AB   XC-941       B.SC. PHYSICAL SCIENCES WITH ELECTRONICS    3
# ..   ...  ...      ...                                            ...  ...
# 83    84   XA  XC-1257                B.SC.(HONOURS) COMPUTER SCIENCE    3
# 84    85   AB    Z-722                    B.SC. (HONOURS) MATHEMATICS    3
# 85    86   XX    Z-773                    B.SC. (HONOURS) MATHEMATICS    3
# 86    87   XA   XC-704  B.SC. PHYSICAL SCIENCES WITH COMPUTER SCIENCE    3
# 87    88   XA  XC-1257                B.SC.(HONOURS) COMPUTER SCIENCE    3
#
#     Type                                    Preference 1  \
# ...

# %% [markdown]
# ## Writing DF as excelsheet

# %%
print(hierrachydata)
# Out:
#                Marks1  Marks2  Marks3
# Course Rollno
# PMCS   Z-1         67      56      89
#        Z-3         78      56      56
#        Z-4         76      67      45
#        Z-5         68      57      90
#        Z-6         68      46      77
#        Z-7         79      57      57
# PS     Z-2         69      58      91
#        Z-3         69      47      78
#        Z-4         80      58      58
#        Z-5         78      69      47

# %%
writer = pd.ExcelWriter('newfile.xlsx')

# %%
hierrachydata.to_excel(writer, 'Sheet1')
writer.save()

# %% [markdown]
# # python csv module to work with csv file with special user-specified delimiters

# %%
import csv
f = open('weather.csv')

# %%
reader = csv.reader(f)

# %%
for line in reader:
    print(line)
# Out:
# ['Season', 'Weather', 'Tourist', 'Labels']
# ['Summer', 'Pleasant', 'like', 'Yes']
# ['Summer', 'Hot', 'dislike', 'Yes']
# ['Summer', 'Pleasant', 'like', 'Yes']
# ['winter', 'Harsh', 'like', 'Yes']
# ['winter', 'Pleasant', 'like', 'No']
# ['autumn', 'Dry', 'dislike', 'Yes']
# ['autumn', 'Pleasant', 'dislike', 'Yes']
# ['autumn', 'Harsh', 'NULL', 'No']
# ['Spring', 'Pleasant', 'like', 'NULL']

# %%
# open the file using open() function
filetxt = open("D:\cs(h)Vsem Data analysis and visulaization 2021\programs\pandas\weather-1.txt")
   
# Reading from file
print(filetxt.read())
 
# closing the file
filetxt.close()
 
# try to write in the file after closing
filetxt.write(" Attempt to write on a closed file !")
# Out:
# Season	Weather	Tourist	Labels
# Summer	Pleasant	like	Yes
# Summer	Hot	dislike	Yes
# Summer	Pleasant	like	Yes
# winter	Harsh	like	Yes
# winter	Pleasant	like	No
# autumn	Dry	dislike	Yes
# autumn	Pleasant	dislike	Yes
# autumn	Harsh	NULL	No
# Spring	Pleasant	like	NULL
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SHARAN~1\AppData\Local\Temp/ipykernel_22932/1763569272.py in <module>
#       9
#      10 # try to write in the file after closing
# ---> 11 filetxt.write(" Attempt to write on a closed file !")
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# ## alternative without closing file reader explicitly, use with and reader()explicitly

# %%
with open('weather.csv') as f:
    lines = list(csv.reader(f))

# %%
lines
# Out:
# [['Season', 'Weather', 'Tourist', 'Labels'],
#  ['Summer', 'Pleasant', 'like', 'Yes'],
#  ['Summer', 'Hot', 'dislike', 'Yes'],
#  ['Summer', 'Pleasant', 'like', 'Yes'],
#  ['winter', 'Harsh', 'like', 'Yes'],
#  ['winter', 'Pleasant', 'like', 'No'],
#  ['autumn', 'Dry', 'dislike', 'Yes'],
#  ['autumn', 'Pleasant', 'dislike', 'Yes'],
#  ['autumn', 'Harsh', 'NULL', 'No'],
#  ['Spring', 'Pleasant', 'like', 'NULL']]

# %% [markdown]
# ## reading line by line and then storing data in data dictionary which is mapped to DF

# %%
with open('weather.csv') as f:
  for line in f:
    print(line, len(line))
# Out:
# Season,Weather,Tourist,Labels
#  30
# Summer,Pleasant,like,Yes
#  25
# Summer,Hot,dislike,Yes
#  23
# Summer,Pleasant,like,Yes
#  25
# winter,Harsh,like,Yes
#  22
# winter,Pleasant,like,No
#  24
# autumn,Dry,dislike,Yes
#  23
# autumn,Pleasant,dislike,Yes
#  28
# autumn,Harsh,NULL,No
#  21
# Spring,Pleasant,like,NULL
#  26

# %%
header,values=lines[0],lines[1:]

# %%
header
# Out:
# ['Season', 'Weather', 'Tourist', 'Labels']

# %%
values
# Out:
# [['Summer', 'Pleasant', 'like', 'Yes'],
#  ['Summer', 'Hot', 'dislike', 'Yes'],
#  ['Summer', 'Pleasant', 'like', 'Yes'],
#  ['winter', 'Harsh', 'like', 'Yes'],
#  ['winter', 'Pleasant', 'like', 'No'],
#  ['autumn', 'Dry', 'dislike', 'Yes'],
#  ['autumn', 'Pleasant', 'dislike', 'Yes'],
#  ['autumn', 'Harsh', 'NULL', 'No'],
#  ['Spring', 'Pleasant', 'like', 'NULL']]

# %%
type(values)
# Out:
# list

# %%
values
# Out:
# [['Summer', 'Pleasant', 'like', 'Yes'],
#  ['Summer', 'Hot', 'dislike', 'Yes'],
#  ['Summer', 'Pleasant', 'like', 'Yes'],
#  ['winter', 'Harsh', 'like', 'Yes'],
#  ['winter', 'Pleasant', 'like', 'No'],
#  ['autumn', 'Dry', 'dislike', 'Yes'],
#  ['autumn', 'Pleasant', 'dislike', 'Yes'],
#  ['autumn', 'Harsh', 'NULL', 'No'],
#  ['Spring', 'Pleasant', 'like', 'NULL']]

# %% [markdown]
# ## The * in a function call "unpacks" a list (or other iterable), making each of its elements a separate argument.

# %% [markdown]
# ## changing column to row (as in transpose)

# %%
list(zip(*values))
# Out:
# [('Summer',
#   'Summer',
#   'Summer',
#   'winter',
#   'winter',
#   'autumn',
#   'autumn',
#   'autumn',
#   'Spring'),
#  ('Pleasant',
#   'Hot',
#   'Pleasant',
#   'Harsh',
#   'Pleasant',
#   'Dry',
#   'Pleasant',
#   'Harsh',
#   'Pleasant'),
#  ('like',
#   'dislike',
#   'like',
#   'like',
#   'like',
#   'dislike',
#   'dislike',
#   'NULL',
#   'like'),
#  ('Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'NULL')]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'Season': ('Summer',
#   'Summer',
#   'Summer',
#   'winter',
#   'winter',
#   'autumn',
#   'autumn',
#   'autumn',
#   'Spring'),
#  'Weather': ('Pleasant',
#   'Hot',
#   'Pleasant',
#   'Harsh',
#   'Pleasant',
#   'Dry',
#   'Pleasant',
#   'Harsh',
#   'Pleasant'),
#  'Tourist': ('like',
#   'dislike',
#   'like',
#   'like',
#   'like',
#   'dislike',
#   'dislike',
#   'NULL',
#   'like'),
#  'Labels': ('Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'NULL')}

# %%
pd.DataFrame(data_dict)
# Out:
#    Season   Weather  Tourist Labels
# 0  Summer  Pleasant     like    Yes
# 1  Summer       Hot  dislike    Yes
# 2  Summer  Pleasant     like    Yes
# 3  winter     Harsh     like    Yes
# 4  winter  Pleasant     like     No
# 5  autumn       Dry  dislike    Yes
# 6  autumn  Pleasant  dislike    Yes
# 7  autumn     Harsh     NULL     No
# 8  Spring  Pleasant     like   NULL

# %% [markdown]
# ## Mentioning specific delimiters and using it while reading/writing

# %%
f1=open('file-delimiters.txt')

# %%
reader = csv.reader(f1,delimiter='*')
for lines in reader:
  print('| '.join(lines))
# Out:
# A| B| 101
# B| C| 102
# C| D| 302
# E,F| 105

# %% [markdown]
# ## once the iterator is exhausted, it needs to be reset with new values

# %%
#f1=open('file-delimiters.txt')
reader = csv.reader(f1, delimiter='*')
for lines in reader:
  print(lines)
# Out:
# ['A', 'B', '101']
# ['B', 'C', '102']
# ['C', 'D', '302']
# ['E,F', '105']

# %% [markdown]
# # Web APIs for data using 'requests' which:
#
#
# *   used for making HTTP requests in Python.
# *   provides simple mechanism by abstracting the complexities of making HTTP requests for interacting with services and consuming data in the application.

# %% [markdown]
# ## provides two powerful methods: get() and POST()
# The GET method is used to get or retrieve data from a specified resource.  by using requests.get() which returns a status_code to indicate the status of request. Code :
#
# *   200:  means request was successful and the server responded with the data you were requesting.
# *   404: No source found
#
# *   204: successful but no data and many more
#
#
# ## Let us try to retrieve 30 GitHub issues for PANDAS on GitHub

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ## status_code returned is 200, which means request was successful and the server responded with the data that was requested.

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# ## used Headers to get useful information like content type of the response payload and a time limit on how long to cache the response.

# %%
response.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Fri, 02 Sep 2022 07:48:02 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"b3e821dfe54e6c0e237d8963bfd97dd3767ccb26c72b433a43c888d53b9648e5"', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/repositories/858127/issues?page=2>; rel="next", <https://api.github.com/repositories/858127/issues?page=117>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options
# ...

# %% [markdown]
# ## converting the collected responses into data (excluding comments) dictionaty using json() method. Each element in data is a dictionary containing all of the data found on a GitHub issue page (except for the comments)

# %%
data = response.json()
data[1]['title']
# Out:
# 'TST: Address/catch more test warnings'

# %%
type(data)
# Out:
# list

# %%
issues = pd.DataFrame(data, columns=['number', 'title',
                                     'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    48359                         pytest: Use colored output
# 1    48358              TST: Address/catch more test warnings
# 2    48357  DOC: add pd.Grouper type to groupby by argumen...
# 3    48355  BUG: 1.5.0rc0 extract_links modifies type firs...
# 4    48354                           CI/DEBUG: Debug timeouts
# 5    48353  Backport PR #48254 on branch 1.5.x (REF: avoid...
# 6    48352               GitHub Actions: Use larger instances
# 7    48351  Added test for `assert_index_equal` to check t...
# 8    48350  Backport PR #48334 on branch 1.5.x (BUG: read_...
# 9    48349                           STYLE: upgrade codespell
# 10   48348                           REF: simplify Block.diff
# 11   48347                           ENH: __pandas_priority__
# 12   48346    Governance: decision making on technical topics
# 13   48340  BUG: `.describe()` on `unsigned` types is resu...
# ...

# %% [markdown]
# ## Second example: To leverage the Washington city’s OpenData portal having crime data

# %%
url = 'https://maps2.dcgis.dc.gov/dcgis/rest/services/FEEDS/MPD/MapServer/2/query?where=1%3D1&outFields=*&outSR=4326&f=json'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['displayFieldName', 'fieldAliases', 'geometryType', 'spatialReference', 'fields', 'features', 'exceededTransferLimit'])

# %%
data
# Out:
# {'displayFieldName': 'CCN',
#  'fieldAliases': {'CCN': 'CCN',
#   'REPORT_DAT': 'REPORT_DATE',
#   'SHIFT': 'SHIFT',
#   'METHOD': 'METHOD',
#   'OFFENSE': 'OFFENSE',
#   'BLOCK': 'BLOCK',
#   'XBLOCK': 'XBLOCK',
#   'YBLOCK': 'YBLOCK',
#   'WARD': 'WARD',
#   'ANC': 'ANC',
#   'DISTRICT': 'DISTRICT',
#   'PSA': 'PSA',
#   'NEIGHBORHOOD_CLUSTER': 'NEIGHBORHOOD_CLUSTER',
#   'BLOCK_GROUP': 'BLOCK_GROUP',
#   'CENSUS_TRACT': 'CENSUS_TRACT',
#   'VOTING_PRECINCT': 'VOTING_PRECINCT',
#   'LATITUDE': 'LATITUDE',
#   'LONGITUDE': 'LONGITUDE',
#   'BID': 'BID',
#   'START_DATE': 'START_DATE',
#   'END_DATE': 'END_DATE',
#   'OBJECTID': 'OBJECTID',
#   'OCTO_RECORD_ID': 'OCTO_RECORD_ID'},
#  'geometryType': 'esriGeometryPoint',
#  'spatialReference': {'wkid': 4326, 'latestWkid': 4326},
#  'fields': [{'name': 'CCN',
#    'type': 'esriFieldTypeString',
#    'alias': 'CCN',
#    'length': 8},
#   {'name': 'REPORT_DAT',
#    'type': 'esriFieldTypeDate',
#    'alias': 'REPORT_DATE',
# ...

# %%
data['features']
# Out:
# [{'attributes': {'CCN': '20081025',
#    'REPORT_DAT': 1591017112000,
#    'SHIFT': 'DAY',
#    'METHOD': 'OTHERS',
#    'OFFENSE': 'BURGLARY',
#    'BLOCK': '1700 - 1799 BLOCK OF CONNECTICUT AVENUE NW',
#    'XBLOCK': 396046.2,
#    'YBLOCK': 138387.65,
#    'WARD': '2',
#    'ANC': '2B',
#    'DISTRICT': '2',
#    'PSA': '208',
#    'NEIGHBORHOOD_CLUSTER': 'Cluster 6',
#    'BLOCK_GROUP': '005502 1',
#    'CENSUS_TRACT': '005502',
#    'VOTING_PRECINCT': 'Precinct 14',
#    'LATITUDE': 38.9133446172,
#    'LONGITUDE': -77.0455886991,
#    'BID': 'DUPONT CIRCLE',
#    'START_DATE': 1590993053000,
#    'END_DATE': 1591009256000,
#    'OBJECTID': 210841497,
#    'OCTO_RECORD_ID': None},
#   'geometry': {'x': -77.04559099760316, 'y': 38.9133524064213}},
#  {'attributes': {'CCN': '20083361',
#    'REPORT_DAT': 1591372706000,
#    'SHIFT': 'DAY',
#    'METHOD': 'OTHERS',
#    'OFFENSE': 'THEFT F/AUTO',
#    'BLOCK': '5700 - 5799 BLOCK OF 3RD PLACE NW',
#    'XBLOCK': 398517.69,
# ...

# %%
df = pd.json_normalize(data, 'features')
df.head(10)
# Out:
#   attributes.CCN  attributes.REPORT_DAT attributes.SHIFT attributes.METHOD  \
# 0       20081025          1591017112000              DAY            OTHERS
# 1       20083361          1591372706000              DAY            OTHERS
# 2       20083365          1591380075000              DAY            OTHERS
# 3       20047859          1584582953000          EVENING            OTHERS
# 4       20047879          1584585661000          EVENING            OTHERS
# 5       20047904          1584590943000         MIDNIGHT            OTHERS
# 6       20047963          1584608850000         MIDNIGHT            OTHERS
# 7       20047997          1584625087000              DAY            OTHERS
# 8       20048013          1584627765000              DAY            OTHERS
# 9       20051050          1585240002000              DAY            OTHERS
#
#   attributes.OFFENSE                            attributes.BLOCK  \
# 0           BURGLARY  1700 - 1799 BLOCK OF CONNECTICUT AVENUE NW
# ...
