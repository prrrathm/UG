# %% [markdown]
# ## data cleaning part-I
# Data Cleaning and Preperation: required to remove anomalies/outlier unwanted data and to get data in proper format so that furher processing could be done to get knowledge**
# Data Preperation include:
#
#
# *   Data Cleaning
# *   Data Transformation
#
#
# *   Data loading and rearranging

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### in colab use DF=pd.read_csv('/content/weather.csv',na_values=np.nan)

# %%
DF=pd.read_csv('weather.csv',na_values=np.nan)
DF
# Out:
#    Season   Weather  Tourist Labels
# 0  Summer  Pleasant     like    Yes
# 1  Summer       Hot  dislike    Yes
# 2  Summer  Pleasant     like    Yes
# 3  winter     Harsh     like    Yes
# 4  winter  Pleasant     like     No
# 5  autumn       Dry  dislike    Yes
# 6  autumn  Pleasant  dislike    Yes
# 7  autumn     Harsh      NaN     No
# 8  Spring  Pleasant     like    NaN

# %% [markdown]
# ## assigning Null/Na values

# %%
DF.iloc[3]=None

# %% [markdown]
# ## checking for NULL values in Series and Data Frame

# %%
DF
# Out:
#    Season   Weather  Tourist Labels
# 0  Summer  Pleasant     like    Yes
# 1  Summer       Hot  dislike    Yes
# 2  Summer  Pleasant     like    Yes
# 3    None      None     None   None
# 4  winter  Pleasant     like     No
# 5  autumn       Dry  dislike    Yes
# 6  autumn  Pleasant  dislike    Yes
# 7  autumn     Harsh      NaN     No
# 8  Spring  Pleasant     like    NaN

# %%
DF.isnull()
# Out:
#    Season  Weather  Tourist  Labels
# 0   False    False    False   False
# 1   False    False    False   False
# 2   False    False    False   False
# 3    True     True     True    True
# 4   False    False    False   False
# 5   False    False    False   False
# 6   False    False    False   False
# 7   False    False     True   False
# 8   False    False    False    True

# %%
DF
# Out:
#    Season   Weather  Tourist Labels
# 0  Summer  Pleasant     like    Yes
# 1  Summer       Hot  dislike    Yes
# 2  Summer  Pleasant     like    Yes
# 3    None      None     None   None
# 4  winter  Pleasant     like     No
# 5  autumn       Dry  dislike    Yes
# 6  autumn  Pleasant  dislike    Yes
# 7  autumn     Harsh      NaN     No
# 8  Spring  Pleasant     like    NaN

# %%
DF.notnull()
# Out:
#    Season  Weather  Tourist  Labels
# 0    True     True     True    True
# 1    True     True     True    True
# 2    True     True     True    True
# 3   False    False    False   False
# 4    True     True     True    True
# 5    True     True     True    True
# 6    True     True     True    True
# 7    True     True    False    True
# 8    True     True     True   False

# %% [markdown]
# ## count NULL values in Series and each column in Data Frame

# %%
DF.isna()
# Out:
#    Season  Weather  Tourist  Labels
# 0   False    False    False   False
# 1   False    False    False   False
# 2   False    False    False   False
# 3    True     True     True    True
# 4   False    False    False   False
# 5   False    False    False   False
# 6   False    False    False   False
# 7   False    False     True   False
# 8   False    False    False    True

# %%
DF.count()
# Out:
# Season     8
# Weather    8
# Tourist    7
# Labels     7
# dtype: int64

# %%
DF.isna().count()
# Out:
# Season     9
# Weather    9
# Tourist    9
# Labels     9
# dtype: int64

# %% [markdown]
# ## retrieving not null values only

# %%
DF
# Out:
#    Season   Weather  Tourist Labels
# 0  Summer  Pleasant     like    Yes
# 1  Summer       Hot  dislike    Yes
# 2  Summer  Pleasant     like    Yes
# 3    None      None     None   None
# 4  winter  Pleasant     like     No
# 5  autumn       Dry  dislike    Yes
# 6  autumn  Pleasant  dislike    Yes
# 7  autumn     Harsh      NaN     No
# 8  Spring  Pleasant     like    NaN

# %% [markdown]
# ## find if  a column has a null values

# %%
DF.count()!=len(DF)
# Out:
# Season     True
# Weather    True
# Tourist    True
# Labels     True
# dtype: bool

# %%
DF.isnull().sum()
# Out:
# Season     1
# Weather    1
# Tourist    2
# Labels     2
# dtype: int64

# %% [markdown]
# ## dropping rows with atleast one NA

# %%
cleaned = DF.dropna()

# %%
DF
# Out:
#    Season   Weather  Tourist Labels
# 0  Summer  Pleasant     like    Yes
# 1  Summer       Hot  dislike    Yes
# 2  Summer  Pleasant     like    Yes
# 3    None      None     None   None
# 4  winter  Pleasant     like     No
# 5  autumn       Dry  dislike    Yes
# 6  autumn  Pleasant  dislike    Yes
# 7  autumn     Harsh      NaN     No
# 8  Spring  Pleasant     like    NaN

# %%
cleaned
# Out:
#    Season   Weather  Tourist Labels
# 0  Summer  Pleasant     like    Yes
# 1  Summer       Hot  dislike    Yes
# 2  Summer  Pleasant     like    Yes
# 4  winter  Pleasant     like     No
# 5  autumn       Dry  dislike    Yes
# 6  autumn  Pleasant  dislike    Yes

# %%
DF['extra']=np.nan
DF
# Out:
#    Season   Weather  Tourist Labels  extra
# 0  Summer  Pleasant     like    Yes    NaN
# 1  Summer       Hot  dislike    Yes    NaN
# 2  Summer  Pleasant     like    Yes    NaN
# 3    None      None     None   None    NaN
# 4  winter  Pleasant     like     No    NaN
# 5  autumn       Dry  dislike    Yes    NaN
# 6  autumn  Pleasant  dislike    Yes    NaN
# 7  autumn     Harsh      NaN     No    NaN
# 8  Spring  Pleasant     like    NaN    NaN

# %%
len(DF)
# Out:
# 9

# %%
DF['newcol1']= np.arange(1,len(DF)+1,1)

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  newcol1
# 0  Summer  Pleasant     like    Yes    NaN        1
# 1  Summer       Hot  dislike    Yes    NaN        2
# 2  Summer  Pleasant     like    Yes    NaN        3
# 3    None      None     None   None    NaN        4
# 4  winter  Pleasant     like     No    NaN        5
# 5  autumn       Dry  dislike    Yes    NaN        6
# 6  autumn  Pleasant  dislike    Yes    NaN        7
# 7  autumn     Harsh      NaN     No    NaN        8
# 8  Spring  Pleasant     like    NaN    NaN        9

# %% [markdown]
# ### Find the output?

# %%
DF['cost']=DF['Season'].map(lambda x: 100 if x =='Summer' else (150 if x=='winter' else 200 ))

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  newcol1  cost
# 0  Summer  Pleasant     like    Yes    NaN        1   100
# 1  Summer       Hot  dislike    Yes    NaN        2   100
# 2  Summer  Pleasant     like    Yes    NaN        3   100
# 3    None      None     None   None    NaN        4   200
# 4  winter  Pleasant     like     No    NaN        5   150
# 5  autumn       Dry  dislike    Yes    NaN        6   200
# 6  autumn  Pleasant  dislike    Yes    NaN        7   200
# 7  autumn     Harsh      NaN     No    NaN        8   200
# 8  Spring  Pleasant     like    NaN    NaN        9   200

# %%
DF.drop(axis=1,labels=['newcol1'],inplace=True)

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost
# 0  Summer  Pleasant     like    Yes    NaN   100
# 1  Summer       Hot  dislike    Yes    NaN   100
# 2  Summer  Pleasant     like    Yes    NaN   100
# 3    None      None     None   None    NaN   200
# 4  winter  Pleasant     like     No    NaN   150
# 5  autumn       Dry  dislike    Yes    NaN   200
# 6  autumn  Pleasant  dislike    Yes    NaN   200
# 7  autumn     Harsh      NaN     No    NaN   200
# 8  Spring  Pleasant     like    NaN    NaN   200

# %% [markdown]
# ## dropping row/column on the basis of all NA or any NA values, no in-place change in data frame

# %%
DF.dropna(axis=1,how='all')
# Out:
#    Season   Weather  Tourist Labels  cost
# 0  Summer  Pleasant     like    Yes   100
# 1  Summer       Hot  dislike    Yes   100
# 2  Summer  Pleasant     like    Yes   100
# 3    None      None     None   None   200
# 4  winter  Pleasant     like     No   150
# 5  autumn       Dry  dislike    Yes   200
# 6  autumn  Pleasant  dislike    Yes   200
# 7  autumn     Harsh      NaN     No   200
# 8  Spring  Pleasant     like    NaN   200

# %% [markdown]
# ## Drop na values and keep rows/columns iff there are  valid values as specified in threshold

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost
# 0  Summer  Pleasant     like    Yes    NaN   100
# 1  Summer       Hot  dislike    Yes    NaN   100
# 2  Summer  Pleasant     like    Yes    NaN   100
# 3    None      None     None   None    NaN   200
# 4  winter  Pleasant     like     No    NaN   150
# 5  autumn       Dry  dislike    Yes    NaN   200
# 6  autumn  Pleasant  dislike    Yes    NaN   200
# 7  autumn     Harsh      NaN     No    NaN   200
# 8  Spring  Pleasant     like    NaN    NaN   200

# %%
DF1=DF.copy()

# %%
DF1.dropna(axis=1,thresh=8,inplace=True)

# %%
DF1
# Out:
#    Season   Weather  cost
# 0  Summer  Pleasant   100
# 1  Summer       Hot   100
# 2  Summer  Pleasant   100
# 3    None      None   200
# 4  winter  Pleasant   150
# 5  autumn       Dry   200
# 6  autumn  Pleasant   200
# 7  autumn     Harsh   200
# 8  Spring  Pleasant   200

# %% [markdown]
# ## Filling In Missing Data with user specified data

# %% [markdown]
# ### filled with zero in all columns

# %%
DF.fillna(0)
# Out:
#    Season   Weather  Tourist Labels  extra  cost
# 0  Summer  Pleasant     like    Yes    0.0   100
# 1  Summer       Hot  dislike    Yes    0.0   100
# 2  Summer  Pleasant     like    Yes    0.0   100
# 3       0         0        0      0    0.0   200
# 4  winter  Pleasant     like     No    0.0   150
# 5  autumn       Dry  dislike    Yes    0.0   200
# 6  autumn  Pleasant  dislike    Yes    0.0   200
# 7  autumn     Harsh        0     No    0.0   200
# 8  Spring  Pleasant     like      0    0.0   200

# %% [markdown]
# ### filled na with specified values in specific columns

# %%
DF.fillna({'Tourist':'like'})
# Out:
#    Season   Weather  Tourist Labels  extra  cost
# 0  Summer  Pleasant     like    Yes    NaN   100
# 1  Summer       Hot  dislike    Yes    NaN   100
# 2  Summer  Pleasant     like    Yes    NaN   100
# 3    None      None     like   None    NaN   200
# 4  winter  Pleasant     like     No    NaN   150
# 5  autumn       Dry  dislike    Yes    NaN   200
# 6  autumn  Pleasant  dislike    Yes    NaN   200
# 7  autumn     Harsh     like     No    NaN   200
# 8  Spring  Pleasant     like    NaN    NaN   200

# %%
DF.fillna({'Tourist':'like','extra':100})
# Out:
#    Season   Weather  Tourist Labels  extra  cost
# 0  Summer  Pleasant     like    Yes  100.0   100
# 1  Summer       Hot  dislike    Yes  100.0   100
# 2  Summer  Pleasant     like    Yes  100.0   100
# 3    None      None     like   None  100.0   200
# 4  winter  Pleasant     like     No  100.0   150
# 5  autumn       Dry  dislike    Yes  100.0   200
# 6  autumn  Pleasant  dislike    Yes  100.0   200
# 7  autumn     Harsh     like     No  100.0   200
# 8  Spring  Pleasant     like    NaN  100.0   200

# %% [markdown]
# ## fillna() with ffill()/bfill() method
# ### adding a new column of numeric value

# %%
DF['numcol']=np.arange(len(DF))
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes    NaN   100       0
# 1  Summer       Hot  dislike    Yes    NaN   100       1
# 2  Summer  Pleasant     like    Yes    NaN   100       2
# 3    None      None     None   None    NaN   200       3
# 4  winter  Pleasant     like     No    NaN   150       4
# 5  autumn       Dry  dislike    Yes    NaN   200       5
# 6  autumn  Pleasant  dislike    Yes    NaN   200       6
# 7  autumn     Harsh      NaN     No    NaN   200       7
# 8  Spring  Pleasant     like    NaN    NaN   200       8

# %%
DF.loc[4,'numcol']=None
DF.loc[6,'numcol']=None
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes    NaN   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN    NaN   200     8.0

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes    NaN   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN    NaN   200     8.0

# %%
DF.fillna(method='ffill')
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes    NaN   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3  Summer  Pleasant     like    Yes    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     3.0
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     5.0
# 7  autumn     Harsh  dislike     No    NaN   200     7.0
# 8  Spring  Pleasant     like     No    NaN   200     8.0

# %% [markdown]
# ### ffill() for fixed threshold

# %%
DF.loc[0,'extra']=10

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN    NaN   200     8.0

# %%
DF.fillna(method='ffill',limit=2)
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes   10.0   100     1.0
# 2  Summer  Pleasant     like    Yes   10.0   100     2.0
# 3  Summer  Pleasant     like    Yes    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     3.0
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     5.0
# 7  autumn     Harsh  dislike     No    NaN   200     7.0
# 8  Spring  Pleasant     like     No    NaN   200     8.0

# %%
DF.loc[len(DF)-1,'extra']=50

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0

# %%
DF.fillna(method='bfill',limit=2)
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3  winter  Pleasant     like     No    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     5.0
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes   50.0   200     7.0
# 7  autumn     Harsh     like     No   50.0   200     7.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0

# %% [markdown]
# ### replace numeric column'na values with mean() in fillna()

# %%
DF.fillna(DF.mean())
# Out:
#    Season   Weather  Tourist Labels  extra  cost    numcol
# 0  Summer  Pleasant     like    Yes   10.0   100  0.000000
# 1  Summer       Hot  dislike    Yes   30.0   100  1.000000
# 2  Summer  Pleasant     like    Yes   30.0   100  2.000000
# 3    None      None     None   None   30.0   200  3.000000
# 4  winter  Pleasant     like     No   30.0   150  3.714286
# 5  autumn       Dry  dislike    Yes   30.0   200  5.000000
# 6  autumn  Pleasant  dislike    Yes   30.0   200  3.714286
# 7  autumn     Harsh      NaN     No   30.0   200  7.000000
# 8  Spring  Pleasant     like    NaN   50.0   200  8.000000

# %% [markdown]
# ## count frequency of the specified column

# %%
DF['Season'].value_counts()
# Out:
# Summer    3
# autumn    3
# winter    1
# Spring    1
# Name: Season, dtype: int64

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  numcol
# 0  Summer  Pleasant      NaN   None   10.0     0.0
# 1  Summer       Hot  dislike    Yes    NaN     1.0
# 2  Summer  Pleasant     like    Yes    NaN     2.0
# 3  winter     Harsh     like    Yes    NaN     3.0
# 4  winter  Pleasant     like     No    NaN     NaN
# 5  autumn       Dry  dislike    Yes    NaN     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN     NaN
# 7  autumn     Harsh      NaN     No    NaN     7.0
# 8  Spring  Pleasant     like    NaN    NaN     8.0

# %% [markdown]
# # find the output?

# %%
S=DF['Season'].value_counts()
DF['Season'].fillna(S.idxmax())
# Out:
# 0    Summer
# 1    Summer
# 2    Summer
# 3    Summer
# 4    winter
# 5    autumn
# 6    autumn
# 7    autumn
# 8    Spring
# Name: Season, dtype: object

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0

# %%
DF[['Season','Weather']].value_counts()
# Out:
# Season  Weather
# Summer  Pleasant    2
# Spring  Pleasant    1
# Summer  Hot         1
# autumn  Dry         1
#         Harsh       1
#         Pleasant    1
# winter  Pleasant    1
# dtype: int64

# %% [markdown]
# ## Problem: replace null value in each column with value appearing maximum time and store in new DF
# Hint: First count frequency of values in each column

# %%
DS=pd.DataFrame()
for i in DF.columns:
  val=DF[i].value_counts().idxmax()
  DS[i]=DF[i].fillna(val,inplace=False)

# %%
DS
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes   50.0   100     1.0
# 2  Summer  Pleasant     like    Yes   50.0   100     2.0
# 3  Summer  Pleasant     like    Yes   50.0   200     3.0
# 4  winter  Pleasant     like     No   50.0   150     0.0
# 5  autumn       Dry  dislike    Yes   50.0   200     5.0
# 6  autumn  Pleasant  dislike    Yes   50.0   200     0.0
# 7  autumn     Harsh     like     No   50.0   200     7.0
# 8  Spring  Pleasant     like    Yes   50.0   200     8.0

# %% [markdown]
# # data Transformation
# Removing duplicate rows

# %%
DF.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
DF=DF.append(DF.iloc[len(DF)-1])

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0

# %%
DF.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 8     True
# dtype: bool

# %%
DF.drop_duplicates(inplace=True)
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0

# %%
DF
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0

# %%
DF.drop_duplicates(['Labels'], keep='last')
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0

# %%
DF.drop_duplicates(['Labels'], keep='first')
# Out:
#    Season   Weather Tourist Labels  extra  numcol
# 0  Summer  Pleasant    like    Yes   10.0     0.0
# 3    None      None    None   None    NaN     3.0
# 4  winter  Pleasant    like     No    NaN     NaN

# %%
DF.drop_duplicates(['Labels','numcol'], keep='first')
# Out:
#    Season   Weather  Tourist Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Yes   10.0   100     0.0
# 1  Summer       Hot  dislike    Yes    NaN   100     1.0
# 2  Summer  Pleasant     like    Yes    NaN   100     2.0
# 3    None      None     None   None    NaN   200     3.0
# 4  winter  Pleasant     like     No    NaN   150     NaN
# 5  autumn       Dry  dislike    Yes    NaN   200     5.0
# 6  autumn  Pleasant  dislike    Yes    NaN   200     NaN
# 7  autumn     Harsh      NaN     No    NaN   200     7.0
# 8  Spring  Pleasant     like    NaN   50.0   200     8.0

# %% [markdown]
# ## Transformation using function mapping
#
# Changing/adding a new column using transoformation

# %% [markdown]
# ## problem: Assign rainlabels in Dataframe according to season type using data dictionary dict1

# %%
DF.fillna(method='ffill',inplace=True)

# %%
dict1={'SUMMER':'rain','AUTUMN':'Norain','SPRING':'rain','WINTER':'Norain'}

# %%
DF['Season'].map(lambda x: dict1[x.upper()])
# Out:
# 0      rain
# 1      rain
# 2      rain
# 3      rain
# 4    Norain
# 5    Norain
# 6    Norain
# 7    Norain
# 8      rain
# Name: Season, dtype: object

# %%
UpSeason = DF['Season'].str.upper()
UpSeason 
DF['Labels'] = UpSeason.map(dict1)
DF
# Out:
#    Season   Weather  Tourist  Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    rain   10.0   100     0.0
# 1  Summer       Hot  dislike    rain   10.0   100     1.0
# 2  Summer  Pleasant     like    rain   10.0   100     2.0
# 3  Summer  Pleasant     like    rain   10.0   200     3.0
# 4  winter  Pleasant     like  Norain   10.0   150     3.0
# 5  autumn       Dry  dislike  Norain   10.0   200     5.0
# 6  autumn  Pleasant  dislike  Norain   10.0   200     5.0
# 7  autumn     Harsh  dislike  Norain   10.0   200     7.0
# 8  Spring  Pleasant     like    rain   50.0   200     8.0

# %% [markdown]
# ### find output?

# %%
UpSeason = DF['Season'].str.upper()
DF['Labels'] = UpSeason.map(dict1).str.title()
DF
# Out:
#    Season   Weather  Tourist  Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Rain   10.0   100     0.0
# 1  Summer       Hot  dislike    Rain   10.0   100     1.0
# 2  Summer  Pleasant     like    Rain   10.0   100     2.0
# 3  Summer  Pleasant     like    Rain   10.0   200     3.0
# 4  winter  Pleasant     like  Norain   10.0   150     3.0
# 5  autumn       Dry  dislike  Norain   10.0   200     5.0
# 6  autumn  Pleasant  dislike  Norain   10.0   200     5.0
# 7  autumn     Harsh  dislike  Norain   10.0   200     7.0
# 8  Spring  Pleasant     like    Rain   50.0   200     8.0

# %% [markdown]
# ##  values  using replace()

# %%
DF
# Out:
#    Season   Weather  Tourist  Labels  extra  numcol
# 0  Summer  Pleasant     like    rain   10.0     0.0
# 1  Summer       Hot  dislike    rain   10.0     1.0
# 2  Summer  Pleasant     like    rain   10.0     2.0
# 3  Summer  Pleasant     like    rain   10.0     3.0
# 4  winter  Pleasant     like  Norain   10.0     3.0
# 5  autumn       Dry  dislike  Norain   10.0     5.0
# 6  autumn  Pleasant  dislike  Norain   10.0     5.0
# 7  autumn     Harsh  dislike  Norain   10.0     7.0
# 8  Spring  Pleasant     like    rain   50.0     8.0

# %%
DF.replace('Harsh', np.nan)
# Out:
#    Season   Weather  Tourist  Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Rain   10.0   100     0.0
# 1  Summer       Hot  dislike    Rain   10.0   100     1.0
# 2  Summer  Pleasant     like    Rain   10.0   100     2.0
# 3  Summer  Pleasant     like    Rain   10.0   200     3.0
# 4  winter  Pleasant     like  Norain   10.0   150     3.0
# 5  autumn       Dry  dislike  Norain   10.0   200     5.0
# 6  autumn  Pleasant  dislike  Norain   10.0   200     5.0
# 7  autumn       NaN  dislike  Norain   10.0   200     7.0
# 8  Spring  Pleasant     like    Rain   50.0   200     8.0

# %%
DF.replace(['Harsh','Dry'], [np.nan,'Wet'])
# Out:
#    Season   Weather  Tourist  Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Rain   10.0   100     0.0
# 1  Summer       Hot  dislike    Rain   10.0   100     1.0
# 2  Summer  Pleasant     like    Rain   10.0   100     2.0
# 3  Summer  Pleasant     like    Rain   10.0   200     3.0
# 4  winter  Pleasant     like  Norain   10.0   150     3.0
# 5  autumn       Wet  dislike  Norain   10.0   200     5.0
# 6  autumn  Pleasant  dislike  Norain   10.0   200     5.0
# 7  autumn       NaN  dislike  Norain   10.0   200     7.0
# 8  Spring  Pleasant     like    Rain   50.0   200     8.0

# %% [markdown]
# ### using dictionary, set replace values

# %%
DF.replace({'Harsh': np.nan,'Dry':'Wet'})
# Out:
#    Season   Weather  Tourist  Labels  extra  numcol
# 0  Summer  Pleasant     like    rain   10.0     0.0
# 1  Summer       Hot  dislike    rain   10.0     1.0
# 2  Summer  Pleasant     like    rain   10.0     2.0
# 3  Summer  Pleasant     like    rain   10.0     3.0
# 4  winter  Pleasant     like  Norain   10.0     3.0
# 5  autumn       Wet  dislike  Norain   10.0     5.0
# 6  autumn  Pleasant  dislike  Norain   10.0     5.0
# 7  autumn       NaN  dislike  Norain   10.0     7.0
# 8  Spring  Pleasant     like    rain   50.0     8.0

# %%
DF['extra'].replace(range(10,20),100)
# Out:
# 0    100.0
# 1    100.0
# 2    100.0
# 3    100.0
# 4    100.0
# 5    100.0
# 6    100.0
# 7    100.0
# 8     50.0
# Name: extra, dtype: float64

# %% [markdown]
# ## string functions()

# %%
DF.set_index('Season')
# Out:
#          Weather  Tourist  Labels  extra  cost  numcol
# Season
# Summer  Pleasant     like    Rain   10.0   100     0.0
# Summer       Hot  dislike    Rain   10.0   100     1.0
# Summer  Pleasant     like    Rain   10.0   100     2.0
# Summer  Pleasant     like    Rain   10.0   200     3.0
# winter  Pleasant     like  Norain   10.0   150     3.0
# autumn       Dry  dislike  Norain   10.0   200     5.0
# autumn  Pleasant  dislike  Norain   10.0   200     5.0
# autumn     Harsh  dislike  Norain   10.0   200     7.0
# Spring  Pleasant     like    Rain   50.0   200     8.0

# %%
DF
# Out:
#    Season   Weather  Tourist  Labels  extra  cost  numcol
# 0  Summer  Pleasant     like    Rain   10.0   100     0.0
# 1  Summer       Hot  dislike    Rain   10.0   100     1.0
# 2  Summer  Pleasant     like    Rain   10.0   100     2.0
# 3  Summer  Pleasant     like    Rain   10.0   200     3.0
# 4  winter  Pleasant     like  Norain   10.0   150     3.0
# 5  autumn       Dry  dislike  Norain   10.0   200     5.0
# 6  autumn  Pleasant  dislike  Norain   10.0   200     5.0
# 7  autumn     Harsh  dislike  Norain   10.0   200     7.0
# 8  Spring  Pleasant     like    Rain   50.0   200     8.0

# %%
DF.rename(index=str.title, columns=str.upper)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SHARAN~1\AppData\Local\Temp/ipykernel_20828/84273743.py in <module>
# ----> 1 DF.rename(index=str.title, columns=str.upper)
#
# c:\Users\Sharanjit Kaur\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     310         @wraps(func)
#     311         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 312             return func(*args, **kwargs)
#     313
#     314         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# c:\Users\Sharanjit Kaur\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4439         4  3  6
#    4440         """
# -> 4441         return super().rename(
#    4442             mapper=mapper,
# ...

# %% [markdown]
# ## What is the output?

# %%
DF['Season'].unique()
# Out:
# array(['Summer', 'winter', 'autumn', 'Spring'], dtype=object)

# %%
DF['Season'].nunique()
# Out:
# 4

# %% [markdown]
# ## Problem : Drop rows with more than half null values. For rest of rows
# ## replace na values with mean of that column in case of numeric col,  and replace by value appearing maximum times in that column for non-numeric column
